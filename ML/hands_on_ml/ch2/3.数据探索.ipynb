# %%
# %matplotlib inline
#　只在Jupter notebook展示
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import hashlib
import os
# 指定字体避免画图中文显示乱码
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['font.family']='sans-serif'
matplotlib.rcParams['axes.unicode_minus'] = False # 使负号显示正常

# %%
housing_path = "datasets/housing"
csv_path = os.path.join(housing_path, "housing_train_stratified_sampling.csv")
housing_train_data = pd.read_csv(csv_path)

# %%
housing_train_data.plot(kind="scatter", x='经度',y='维度')
# 查看地理位置分布

# %%
housing_train_data.plot(kind="scatter", x="经度", y="维度", alpha=0.1)
# 设置密度

# %%
housing_train_data.plot(kind="scatter",x="经度",y="维度",alpha=0.4,
                        s=housing_train_data["人口数"]/100,label="人口数",
                        c=housing_train_data["房屋价值中位数"],cmap=plt.get_cmap("jet"),
                        colorbar=True,figsize=(16,9)
                       )
# 将多个属性可视化,并加上不同颜色展示
plt.legend()

# %% [markdown]
# ### 查找关联

# %%
corr_matrix = housing_train_data.corr()

# %%
corr_matrix["房屋价值中位数"].sort_values(ascending=False)
# Out:
# 房屋价值中位数    1.000000
# 收入中位数      0.687160
# 总房间数       0.135097
# 房屋年龄中位数    0.114110
# 家庭数        0.064506
# 总卧室数       0.047689
# 人口数       -0.026920
# 经度        -0.047432
# 维度        -0.142724
# Name: 房屋价值中位数, dtype: float64

# %%
# from pandas.tools.plotting import scatter_matrix
# 每个数值属性对其他数值熟悉的图
attributes=["房屋价值中位数","收入中位数","总房间数","房屋年龄中位数"]
pd.plotting.scatter_matrix(housing_train_data[attributes],figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe5983c79e8>,
# ...
#       dtype=object)

# %%
housing_train_data.plot(kind="scatter",x="收入中位数",y="房屋价值中位数",alpha=0.1)
